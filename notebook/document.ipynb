# %% [markdown]
# # Data Ingestion

# %%
# Document Struncture

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text content I am using to create RAG system",
    metadata={
        "source":"file1.txt",
        "author":"vikas",
        "data_created":"2024-06-01",
        "no_of_pages":"1"
    }
)
doc
# Out:
# Document(metadata={'source': 'file1.txt', 'author': 'vikas', 'data_created': '2024-06-01', 'no_of_pages': '1'}, page_content='this is the main text content I am using to create RAG system')

# %%
# create a simple txt file directory uunder data
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
# Text loader
from langchain_community.document_loaders import TextLoader 
loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
loader
documents=loader.load()
print(documents)
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_9136\3805056335.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
# Directory loader
from langchain_community.document_loaders import DirectoryLoader

# laod all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", # pattern to match files
    loader_cls=TextLoader, # specify the loader class to use for each file
    loader_kwargs={"encoding":"utf-8"},
    show_progress=True
)

documents=dir_loader.load()
documents
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 2418.86it/s]
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
# Directory loader
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

# laod all the pdf files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", # pattern to match files
    loader_cls=PyMuPDFLoader, # specify the loader class to use for each file
    show_progress=True
    
)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 324.53it/s]
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-06T12:35:18+00:00', 'source': '..\\data\\pdf\\Embeddings.pdf', 'file_path': '..\\data\\pdf\\Embeddings.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-06T12:35:18+00:00', 'trapped': '', 'modDate': "D:20260606123518+00'00'", 'creationDate': "D:20260606123518+00'00'", 'page': 0}, page_content='Embeddings\nEmbeddings convert text into vectors representing meaning.\nModels\nOpenAI, BGE, E5, Sentence Transformers.\nUsage\nUsed for similarity search and retrieval.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-06T12:35:18+00:00', 'source': '..\\data\\pdf\\Loaders.pdf', 'file_path': '..\\data\\pdf\\Loaders.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-06T12:35:18+00:00', 'trapped': '', 'modDate': "D:20260606123518+00'00'", 'creationDate': "D:20260606123518+00'00'", 'page': 0}, page_content='Document Loaders\nLoaders ingest data from PDFs, websites, CSVs, databases, and APIs.\nCommon Loaders\nPyPDFLoader, WebBaseLoader, CSVLoader, DirectoryLoader.\nBest Practices\nPreserve metadata such as source, page number, and URL.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-06T12:35:18+00:00', 'source': '..\\data\\pdf\\Parsing.pdf', 'file_path': '..\\data\\pdf\\Parsing.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-06T12:35:18+00:00', 'trapped': '', 'modDate': "D:20260606123518+00'00'", 'creationDate': "D:20260606123518+00'00'", 'page': 0}, page_content='Parsing\nParsing converts raw documents into structured text.\nTypes\nText parsing, OCR parsing, layout-aware parsing, multimodal parsing.\nImportance\nGood parsing improves chunking and retrieval quality.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-06T12:34:22+00:00', 'source': '..\\data\\pdf\\RAG_Learning_Notes.pdf', 'file_path': '..\\data\\pdf\\RAG_Learning_Notes.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-06T12:34:22+00:00', 'trapped': '', 'modDate': "D:20260606123422+00'00'", 'creationDate': "D:20260606123422+00'00'", 'page': 0}, page_content='RAG (Retrieval-Augmented Generation) Learning\nNotes\n1. What is RAG?\nRAG combines retrieval from external knowledge sources with an LLM to generate grounded\nanswers.\nPipeline: Documents → Parsing → Chunking → Embeddings → Vector DB → Retrieval → LLM\n2. Loaders\nLoaders ingest data from PDFs, websites, databases, CSVs, and text files.\nExamples: PyPDFLoader, WebBaseLoader, CSVLoader, DirectoryLoader.\n3. Parsing\nParsing extracts clean text, tables, and metadata from raw documents.\nGood parsing improves retrieval quality significantly.\n4. Chunking\nLarge documents are split into smaller chunks before embedding.\nCommon strategies: Recursive, Token-based, Semantic chunking.\n5. Embeddings\nEmbeddings convert text into numerical vectors that capture semantic meaning.\n6. Vector Databases\nStore and search embeddings efficiently.\nExamples: Chroma, FAISS, Qdrant, Pinecone.\n7. Retrieval\nUser query is embedded and matched against stored vectors using similarity search.\n8. Generation\nRetrieved chunks are added to the prompt and sent to the LLM.'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-06T12:34:22+00:00', 'source': '..\\data\\pdf\\RAG_Learning_Notes.pdf', 'file_path': '..\\data\\pdf\\RAG_Learning_Notes.pdf', 'total_pages': 2, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-06T12:34:22+00:00', 'trapped': '', 'modDate': "D:20260606123422+00'00'", 'creationDate': "D:20260606123422+00'00'", 'page': 1}, page_content='Sample RAG Flow\nDocuments ↓ Parsing ↓ Chunking ↓ Embeddings ↓ Vector Database ↓ User Query ↓ Similarity\nSearch ↓ Retrieved Chunks ↓ LLM ↓ Answer'),
#  Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-06-06T12:35:18+00:00', 'source': '..\\data\\pdf\\Vector_Databases.pdf', 'file_path': '..\\data\\pdf\\Vector_Databases.pdf', 'total_pages': 1, 'format': 'PDF 1.4', 'title': '(anonymous)', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-06-06T12:35:18+00:00', 'trapped': '', 'modDate': "D:20260606123518+00'00'", 'creationDate': "D:20260606123518+00'00'", 'page': 0}, page_content='Vector Databases\nStore and search embeddings efficiently.\nExamples\nChroma, FAISS, Qdrant, Pinecone, Weaviate.\nRetrieval\nSimilarity search returns relevant chunks for RAG.')]

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# # csv

# %%
from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import CSVLoader

loader = DirectoryLoader(
    "../data/csv",
    glob="**/*.csv",
    loader_cls=CSVLoader,
    show_progress=True
)

csv_documents = loader.load()
csv_documents
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 104.25it/s]
# [Document(metadata={'source': '..\\data\\csv\\data.csv', 'row': 0}, page_content='Name: Vikas\nRole: Data Engineer\nExperience: 3'),
#  Document(metadata={'source': '..\\data\\csv\\data.csv', 'row': 1}, page_content='Name: Rahul\nRole: ML Engineer\nExperience: 2'),
#  Document(metadata={'source': '..\\data\\csv\\data.csv', 'row': 2}, page_content='Name: Akash\nRole: Data Scientist\nExperience: None')]
